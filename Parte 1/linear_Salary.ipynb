# %% [markdown]
# # Linear Regression Model
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load dataset
data = pd.read_csv('Salary Data.csv')
X = data['YearsExperience'].values
Y = data['Salary'].values

# Visualize dataset
plt.scatter(X, Y)
plt.xlabel('Años de experiencia')
plt.ylabel('Salario')
plt.title('Dataset Visualization')
plt.show()

# %%
# MSE and R-squared

# Simple linear regression prediction 
w, b = 2.5, 5 #(arbitrary weights for demo)
Y_pred = w * X + b

# Mean Squared Error (MSE)
mse = np.mean((Y - Y_pred) ** 2)

# R-squared calculation
ss_residual = np.sum((Y - Y_pred) ** 2)
ss_total = np.sum((Y - np.mean(Y)) ** 2)
r_squared = 1 - (ss_residual / ss_total)

print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R-squared: {r_squared:.4f}")
# Out:
# Mean Squared Error (MSE): 6499808630.17
# R-squared: -7.9468

# %%
# Gradient Descent

# Initialize parameters
w, b = 0, 0  # Initial weights and bias
learning_rate = 0.0001
epochs = 400
n = len(X)

# Store history for visualization
loss_history = []

for epoch in range(epochs):
    
    # Predictions
    Y_pred = w * X + b
    
    # Calculate and store loss (MSE)
    loss = np.mean((Y - Y_pred) ** 2)
    loss_history.append(loss)

    # Calculate gradients
    dw = -(2/n) * np.sum((Y - Y_pred) * X)
    db = -(2/n) * np.sum(Y - Y_pred)
    
    # Update weights and bias
    w -= learning_rate * dw
    b -= learning_rate * db


# Final parameters
print(f"Final weight: {w:.4f}, Final bias: {b:.4f}")


# Plotting the loss over epochs
plt.plot(loss_history)
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Loss over Time')
plt.show()


# Plotting the regression line
plt.scatter(X, Y, label='Data')
plt.plot(X, w * X + b, color='red', label='Model')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend() 
plt.show()
# Out:
# Final weight: 12255.5401, Final bias: 2227.9295
